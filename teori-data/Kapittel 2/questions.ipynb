# %% [markdown]
# # Spørsmål 📚

# %% [markdown]
# ## **Forsvarlig og forskriftsmessig stand**
# ### **1. Hva er korrekt om bilens varsellamper?**
# Om varsellampene fungerer som de skal, vil alle lyse opp når du starter motoren, og slukkes automatisk etter noen sekunder.
# Lampenene varierer noe i  utforming og farge fra bil til bil - gjør det kjent med hva lysene for din bil varsler ved å lese
# bilens instruksjonshefte.
#
# ### **2.Hvordan kan du oppdage feil ved bilen?**
# 1. Ved å levere bilen til service eller EU-kontroll
# 2. jeg hører ulyder under kjøring
# 3. Kjøreegenskapene endrer seg.
#
# Det er altså mange forskjellige måter å oppdage feil ved bilen på. Siden det er ditt ansvar at bilen er i forskriftsmessig og forsvarlig stand når du skal kjøre, så bør du kjenne til disse.
#
# Vegtrafikkloven krever at fører før kjøring skal forvisse seg om at kjøretøyet er i forsvarlig og forskriftsmessig stand og at det er forsvarlig og forskriftsmessig lastet.
#
# Fører skal også sørge for at kjøretøyet under bruken er i forsvarlig stand og forsvarlig lastet
#
# Poenget er at du som sjåfør må vite at kjøretøyet er trafikksikkert – for eksempel at bremser og styring fungerer som det skal, at dekkene er av riktig type og har riktig mønsterdybde og at lysene fungerer som de skal.
#
# ### **3.Hvordan kan du oppdage veil ved bilen?**
# 1. Ved å gjennomføre ulike sikkerhetsjekker
# 2. Varsellamper lyser
#
# Det er mange måter å merke feil ved bilen på, så du er ikke avhengig av et verksted for å oppdage dette.
#
# ### **4.Hva vil det si at bilen er i forskriftsmessig stand?**
# 1. At alt det tekniske på bilen er i orden
#
# Forskriftsmessig stand betyr at alt det tekniske på bilen er i orden.
#
# Bilen vil i mange tilfeller fortsatt være forsvarlig å bruke, selv om den skulle vise seg å ikke være i forskriftsmessig stand. Du bør få utbedret eventuelle feil på verksted ved første anledning.
#
# ### **5. At bilen er i forsvarlig stand betyr at den...**
# - er trafikksikker for fører, passasjerer og andre trafikanter
#
# At en bil er i forsvarlig stand betyr at den er trygg å kjøre i de aktuelle kjøreforholdene.
#
# Forskriftsmessig stand betyr at alt det tekniske er i orden. En bil kan være forsvarlig selv om den ikke er i forskriftsmessig stand. For eksempel kan du kjøre en bil med ødelagt frontlykt om det er lyst ute og ellers gode kjøreforhold.
#
# Er det vanskeligere kjøreforhold kan en manglende frontlykt være uforsvarlig - og da har du ikke lov til å kjøre bilen. Derfor bør du alltid sørge for at bilen er i forskriftsmessig stand.
#
# ---

# %% [markdown]
# ## **Kontrolloppgaver - Bremser, hjul og styring** 🚗🔧
# ### **1. Skal bremsene ta kraftigere på bakhjulene enn på forhjulene?**
# Svar: **NEI**
#
# Nei. Bremsene skal ta kraftigere på forhjulene.
#
# Hjul på samme aksel, det vil si begge hjulene foran eller begge hjulene bak, skal ha tilnærmet samme bremsekraft, for å forhindre at bilen «drar» til en side under kraftig oppbremsing.
#
# ### **2. Under kjøring begynner denne lampen å lyse. Hva er riktig?**
# ![ABS](figurer/2_2_2.png)
# * Bilen er ikke lenger i forskriftsmessig stand
#
# Hvis denne lampen lyser tyder det på en feil i ABS-systemet. Bremsene funger fortsatt, men du har ikke lenger noen garanti for at hjulene ikke låser seg ved kraftig oppbremsing.
#
# ### **3. Hvilke av disse dekkvalgene er lovlige?**
# * Piggdekk med 4,0 mm møsterdybde på bar vei i februar.
# * Sommerdekk med 1,9 mm mønsterdybde i styrregn i september
#
# Du må alltid ha dekk som passer til underlaget du skal kjøre på.
# * Sommerdekk med 1,9 mm mønsterdybde i styrtregn i september. Denne er lovlig, i september er det krav om 1,6 mm dekk.
# * Piggdekk med 4,0 mm mønsterdybde på bar vei i februar er lovlig. Minstekrav er 3 mm.
# * Sommerdekk med 3,3 mm mønsterdybde i snøvær i mai. Selv om dette er i sommerperioden er det ikke lov. Du skal alltid ha dekk etter føret og så lenge det er snø eller is i noen form så MÅ du har vinterdekk uansett tid på året. Selv om mønsterdybden er dyp nok i sommerdekket så er mønsteret og gummiblandingen annerledes.
#
# ### **4. Hva er riktig om dette dekket?**
# * Dekkets høyde er 50% av dekkets bredde
#
# ![Dekkets Bredde](figurer/2_4_1.png)
#
# * 225 – dekkets bredde i millimeter ved riktig lufttrykk
# * 50 – dekkets høyde i prosent av dekkets bredde
# * R – radial (alternativet er D for diagonal)
# * 17 – dekkets felgdiameter i tommer
#
# ### **5. Du oppdager at et av dekkene er slitt på begge sider. Hva kan være årsaken?**
# * For lavt lufttrykk i dekket
#
# Dekk som er spesielt slitt på begge sidene tyder på for lavt lufttrykk i dekket.
# Dekk som er spesielt slitt på midten tyder på for høyt lufttrykk i dekket.
# Dekk som er slitt på én side, kan bety feil i forstillingen.
#
# ### **6. Hvilke egenskaper skal bilens styresystem ha?**
# * Styresystemet skal selvopprette bilen
# * Styresystemet skal gjøre det enkelt å dreie på rattet.
#
# Bilen skal være:
# * **selvopprettende:** bilen skal rette seg opp om du slipper rattet i sving
# * **enkel å styre:** bilen skal ha servostyring, som gjør rattet lettere å dreie
# * **presis, med lite dødgang:** hjulene skal begynne å svinge når rattet er dreid maks 3 cm
# * **retningsstabil:** den skal kjøre rett frem når ingen holder på rattet
#
# ### **7.Servostyringen fungerer ikke. Hva er riktig?**
# * Bilen skal fortsatt være i forsvarlig stand.
# * Bilen blir mye tyngre å styre.
#
# Servostyringen gjør bilen lettere å styre.
#
# Om servostyringen slutter å fungere, er ikke bilen lenger i forskriftsmessig stand. Men om du får til å styre den ordentlig så er den fortsatt forsvarlig.
#
# Du kan ikke reparere servostyringen ved å vri på rattet og starte motoren igjen. Den må til verksted.
#
# ### **8. Hva slags bremser er vanlig på en bil?**
# * Parkeringsbrems
# * ABS-brems
#
# Alle biler er utstyrt med fotbrems og parkeringsbrems.
#
# Fotbremsen er av typen blokkeringsfrie bremser. Antiblokkeringssystemet (ABS) hindrer at hjulene låser seg ved kraftig nedbremsing og gir sjåføren muligheten til å styre samtidig som det bremses for full effekt.
#
# ---

# %% [markdown]
# ## **Kontrolloppgaver - Annet teknisk** 🛡️
# ### **1. Hvilke av disse er påbudt å ha med i bilen?**
# * 1. Varseltrekant
# * 2. Refleksvest
#
# ### **2. I hvilke av disse situasjoner bør du umiddeltbart stanse bilen?**
# * 1. Hvis motortemperaturen er for høy
# * 2. Hvis lampen for oljetrykk lyser
#
# Hvis lampen for ABS lyser tyder det på en feil i ABS-systemet. Bremsene fungerer fortsatt, men du har ikke lenger noen garanti for at hjulene ikke låser seg ved kraftig oppbremsing.Men bilen din tar ingen skade av at du kjører med denne feilen.
#
# For høy motortemperatur og feil i oljetrykket er derimot varsellys som indikerer at du bør stanse med en gang.
#
# ### **3. Hva er riktig om bilens batteri?**
# * 1. Batteriet gir strøm til ting som lys og klimaanlegg
# * 2. Hvis batteriet er flatt starter ikke bilen
#
# Bilens batteri leverer strøm til alt på bilen som drives av elektrisitet, for eksempel lys, elektriske vinduer, oppvarming, lufteanlegg (varme og ventilasjon), vindusviskere m.m.
#
# Er batteriet tomt/flatt vil du ikke kunne starte bilen uten hjelp, og du må benytte startkabler.
#
# Bilbatteriet er oppladbart, og kan vare i mange år.
#
# ### **4. Hva er riktig om varseltrekant?**
# Refleksvest bør på først hvis du må ut av bilen for å hente varseltrekant.
#
# Alle biler skal være utstyrt med en varseltrekant.
#
# * Finn frem varseltrekanten og monter den i eller ved bilen. Husk å ta på deg refleksvesten før du går ut av bilen.
# * Gå med varseltrekantens refleksside fra deg slik at motgående trafikk ser deg.
# * Plasser varseltrekanten slik at den blir godt synlig for de andre trafikantene. I tettbygd strøk må du vurdere forholdene for å bestemme hvor langt bak varseltrekanten skal settes. Utenfor tettbygd strøk bør varseltrekanten stå minst 150 meter bak bilen.
#
# ### **5. Hvilke av disse er en del av bilens aktive sikkerhet?**
# 1. Antiskrens
# 2. ABS-bremser
#
# **Bilens aktive sikkerhet er de tingene som hjelper deg å unngå ulykker.**
#
# **Passiv sikkerhet hjelper i en ulykke.**
#
# ---

# %% [markdown]
# ## **Kontrolloppgaver - Tilhenger, vekt og last** 🚚
# ### **1. Hva er riktig?**
# * Det er det laveste tillate koblingslast i vognkortene du må forholde deg til
#
# Reglene for tilhenger og last er kompliserte. Her ser vi nærmere på de forskjellige alternativene:
#
# Når du skal laste henger må du passe på at koblingen på hengeren ikke har mer vekt enn det tåler, og at hengerfestet på bilen ikke har mer vekt enn det tåler. Derfor må du holde deg til den laveste begrensningen.
#
# Man finner ingen informasjon om aktuell totalvekt i vognkortet. Aktuell totalvekt er det tilhengeren faktisk veier, om du putter den på en vekt. Om den er tom, vil aktuell totalvekt være det samme som egenvekt, men det er altså ikke noe punkt i vognkortet som heter aktuell totalvekt.
#
# Med klasse B kan du kjøre med henger med tillatt totalvekt på 750 kg. En personbil, altså det du kjører med klasse B, kan veie opp til 3500 kg. Så, du kan altså veie 4250 kg til sammen: henger på 750 kg, og bil på 3500 kg.
#
# Med klasse B 96 kan man trekke henger som veier mer enn 750 kg, så lenge summen av henger og bil ikke er mer enn 4250 kg. Totalsummen henger+bil er altså den samme som uten B 96, men B 96 lar deg ha tyngre henger om bilen din er lettere. Altså, veier bilen din for eksempel 3200 kg kan du ha en henger på hele 1050 kg. Denne regelen gjelder altså for bil og tilhenger (vogntog) på mellom 3501 kg og 4250 kg. Ikke opp til 7500, som alternativet sier.
#
# ### **2.Hvilke av disse kombinasjonene kan du kjøre med førerkort klasse B?**
# 1. Bil med tillatt totalvekt 2500 kg og tilhenger med tillatt totalvekt 800 kg
# 2. Bil med tillatt totalvekt 3500 kg og tilhenger med tillatt totalvekt 600 kg
#
# Du har lov til å kjøre med:
# * tilhenger med tillatt totalvekt inntil 750 kg – altså slik at samlet tillatt totalvekt for vogntoget (bil og tilhenger til sammen) ikke overstiger 4 250 kg
# * tilhenger med tillatt totalvekt over 750 kg, så lenge tillatt totalvekt for vogntoget ikke overstiger 3 500 kg
#
# ### **3.Hva kan skje om en tilhenger blir for tungt lastet?**
# 1. Kjøreegenskapene kan bli dårligere
# 2. Retningstabiliteten reduseres
#
# For tung tilhenger vil dytte bakenden på bilen ned. Dette endrer kjøreegenskapene:
#
# * Forhjulenes veigrep blir betydelig redusert.
# * Bremselengden øker.
# * Retningsstabiliteten blir redusert.
# * Lyktene på bilen heves, og møtende bilister kan bli blendet.
#
# ### **4. Hva er riktig påstand om elbil?**
# Det selges flere elbiler enn fossilbiler i Norge i dag.
#
# Det selges helt klart flest elbiler i Norge i dag.
#
# Selv om de både ofte veier mer og har kortere rekkevidde sammenlignet med fossilbiler i samme størrelsesklasse, så er de som regel en del billigere i drift.
#
# ### **5.Hva er riktig påstand om elbil?**
# 1. De har ikke gir.
# 2. De har kortere rekkevide enn fossilbiler.
#
# Elbiler har ikke gir og har foreløpig en del kortere rekkevidde en fossile biler. De er ikke nødvendigvis tryggere.
#
# ### **6.Fossile biler ... bruker bensin eller diesel**
# Fossile biler bruker fossilt brensel som bensin eller diesel.
#
# De kan ha manuelle gir, men det har blitt vanligere med automatgir. De har gjerne litt lenger rekkevidde sammenlignet med elbiler, men forurenser også mer.
#
# ### **7. Hvilke påstander er riktig?**
# 1. De fleste bilene har i dag automat
# 2. Du kan kjøre bil med automat, selv om du kjørte opp med manuelle gir
#
# De aller fleste biler i dag har automatgir.
# Du kan kjøre bil med automat hvis du tok oppkjøringen i en bil med manuelt gir, men ikke motsatt.
